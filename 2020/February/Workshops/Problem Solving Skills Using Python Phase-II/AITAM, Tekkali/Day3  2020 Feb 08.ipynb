# %% [markdown]
# # [Pandas](https://pandas.pydata.org/)

# %%
import pandas as pd

# %%
#pip install pandas

# %%
import pandas as pd

# %%
s1 = pd.Series(['a','b','c','d'])
s1
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s1.index = ['num1','num2','num3','num4']
s1
# Out:
# num1    a
# num2    b
# num3    c
# num4    d
# dtype: object

# %%
s1.dtype
# Out:
# dtype('O')

# %%
fruits = ['Apple','Banana','Strawberry','Orange']
veg = ['Carrot','potato','Tomato','beans']
flowers = ['Lily','Sun Flower','Jasmine','Rose']
col = ['Fruits','Vegetables','Flowers']

df = pd.DataFrame([fruits,veg,flowers])
df
# Out:
#         0           1           2       3
# 0   Apple      Banana  Strawberry  Orange
# 1  Carrot      potato      Tomato   beans
# 2    Lily  Sun Flower     Jasmine    Rose

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index = ['Fruits','Vegetables','Flowers']
df
# Out:
#                  0           1           2       3
# Fruits       Apple      Banana  Strawberry  Orange
# Vegetables  Carrot      potato      Tomato   beans
# Flowers       Lily  Sun Flower     Jasmine    Rose

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns = ['item1','item2','item3','item4']
df
# Out:
#              item1       item2       item3   item4
# Fruits       Apple      Banana  Strawberry  Orange
# Vegetables  Carrot      potato      Tomato   beans
# Flowers       Lily  Sun Flower     Jasmine    Rose

# %%
col1 = df['item1']
col1
# Out:
# Fruits         Apple
# Vegetables    Carrot
# Flowers         Lily
# Name: item1, dtype: object

# %%
type(col1)
# Out:
# pandas.core.series.Series

# %%
col2 = df[['item1','item3']]
type(col2)
# Out:
# pandas.core.frame.DataFrame

# %%
col2
# Out:
#              item1       item3
# Fruits       Apple  Strawberry
# Vegetables  Carrot      Tomato
# Flowers       Lily     Jasmine

# %%
df.sort_values(by = 'item3')
# Out:
#              item1       item2       item3   item4
# Flowers       Lily  Sun Flower     Jasmine    Rose
# Fruits       Apple      Banana  Strawberry  Orange
# Vegetables  Carrot      potato      Tomato   beans

# %%
df.to_csv('items.csv')

# %%
roll = '18A51A04'
rollNumbers = []
for num in range(1,101):
    if num < 10:
        s = roll + str(0) + str(num)
    else:
        s = roll + str(num)
    rollNumbers.append(s)
print(rollNumbers)
# Out:
# ['18A51A0401', '18A51A0402', '18A51A0403', '18A51A0404', '18A51A0405', '18A51A0406', '18A51A0407', '18A51A0408', '18A51A0409', '18A51A0410', '18A51A0411', '18A51A0412', '18A51A0413', '18A51A0414', '18A51A0415', '18A51A0416', '18A51A0417', '18A51A0418', '18A51A0419', '18A51A0420', '18A51A0421', '18A51A0422', '18A51A0423', '18A51A0424', '18A51A0425', '18A51A0426', '18A51A0427', '18A51A0428', '18A51A0429', '18A51A0430', '18A51A0431', '18A51A0432', '18A51A0433', '18A51A0434', '18A51A0435', '18A51A0436', '18A51A0437', '18A51A0438', '18A51A0439', '18A51A0440', '18A51A0441', '18A51A0442', '18A51A0443', '18A51A0444', '18A51A0445', '18A51A0446', '18A51A0447', '18A51A0448', '18A51A0449', '18A51A0450', '18A51A0451', '18A51A0452', '18A51A0453', '18A51A0454', '18A51A0455', '18A51A0456', '18A51A0457', '18A51A0458', '18A51A0459', '18A51A0460', '18A51A0461', '18A51A0462', '18A51A0463', '18A51A0464', '18A51A0465', '18A51A0466', '18A51A0467', '18A51A0468', '18A51A0469', '18A51A0470', '18A51A0471', '18
# ...

# %%
import numpy as np
python = [np.random.randint(0,100) for i in range(1,101)]
C = [np.random.randint(0,100) for i in range(1,101)]
pandas = [np.random.randint(0,100) for i in range(1,101)]
numpy = [np.random.randint(0,100) for i in range(1,101)]

# %% [markdown]
# # Creating the Email Id's
#
# ## username@domainName.extension
#
# rollNumber@apssdc.in

# %%
email = [roll + '@apssdc.in' for roll in rollNumbers]

# %%
data = {'Roll Numbers':rollNumbers,'Email': email,'C':C,
 'Python':python,'Pandas':pandas,'Numpy':numpy}
print(data)
# Out:
# {'Roll Numbers': ['18A51A0401', '18A51A0402', '18A51A0403', '18A51A0404', '18A51A0405', '18A51A0406', '18A51A0407', '18A51A0408', '18A51A0409', '18A51A0410', '18A51A0411', '18A51A0412', '18A51A0413', '18A51A0414', '18A51A0415', '18A51A0416', '18A51A0417', '18A51A0418', '18A51A0419', '18A51A0420', '18A51A0421', '18A51A0422', '18A51A0423', '18A51A0424', '18A51A0425', '18A51A0426', '18A51A0427', '18A51A0428', '18A51A0429', '18A51A0430', '18A51A0431', '18A51A0432', '18A51A0433', '18A51A0434', '18A51A0435', '18A51A0436', '18A51A0437', '18A51A0438', '18A51A0439', '18A51A0440', '18A51A0441', '18A51A0442', '18A51A0443', '18A51A0444', '18A51A0445', '18A51A0446', '18A51A0447', '18A51A0448', '18A51A0449', '18A51A0450', '18A51A0451', '18A51A0452', '18A51A0453', '18A51A0454', '18A51A0455', '18A51A0456', '18A51A0457', '18A51A0458', '18A51A0459', '18A51A0460', '18A51A0461', '18A51A0462', '18A51A0463', '18A51A0464', '18A51A0465', '18A51A0466', '18A51A0467', '18A51A0468', '18A51A0469', '18A51A0470', 
# ...

# %%
sdata = pd.DataFrame(data)

# %%
sdata['TotalMarks'] = sdata['C'] + sdata['Python'] + sdata['Numpy'] + sdata['Pandas']

# %%
sdata['Percentage'] = (sdata['TotalMarks'] * 100) / 400

# %%
sdata['Status'] = ['Pass' if data > 40 else 'Fail' for data in sdata['Percentage']]

# %%
# # Exporting the data as excel file to memory
sdata.to_excel('sdata.xlsx',sheet_name='Class1')

# %%
# Exporting the data as csv file to memory
sdata.to_csv('sdata.csv')

# %%
# Import data Python
rdata = pd.read_csv('sdata.csv',index_col = 0)

# %% [markdown]
# ### Getting the top rows

# %%
rdata.head(6)
# Out:
#   Roll Numbers                 Email   C  Python  Pandas  Numpy  TotalMarks  \
# 0   18A51A0401  18A51A0401@apssdc.in  65      27      84     52         228
# 1   18A51A0402  18A51A0402@apssdc.in  24      41       7     44         116
# 2   18A51A0403  18A51A0403@apssdc.in   7      28      52     78         165
# 3   18A51A0404  18A51A0404@apssdc.in  92      52      46     15         205
# 4   18A51A0405  18A51A0405@apssdc.in  17      50      34     27         128
# 5   18A51A0406  18A51A0406@apssdc.in  27       8      40      8          83
#
#    Percentage Status
# 0       57.00   Pass
# 1       29.00   Fail
# 2       41.25   Pass
# 3       51.25   Pass
# 4       32.00   Fail
# 5       20.75   Fail

# %% [markdown]
# ### Getting the Bottom data

# %%
rdata.tail(6)
# Out:
#    Roll Numbers                  Email   C  Python  Pandas  Numpy  TotalMarks  \
# 94   18A51A0495   18A51A0495@apssdc.in   2      54      61     97         214
# 95   18A51A0496   18A51A0496@apssdc.in  28      93      28     56         205
# 96   18A51A0497   18A51A0497@apssdc.in  46      81      78     86         291
# 97   18A51A0498   18A51A0498@apssdc.in  72      17       5     96         190
# 98   18A51A0499   18A51A0499@apssdc.in   2      42      75     61         180
# 99  18A51A04100  18A51A04100@apssdc.in   9       5      80     59         153
#
#     Percentage Status
# 94       53.50   Pass
# 95       51.25   Pass
# 96       72.75   Pass
# 97       47.50   Pass
# 98       45.00   Pass
# 99       38.25   Fail

# %% [markdown]
# ### Getting the Column data

# %%
rdata['Email'].head()
# Out:
# 0    18A51A0401@apssdc.in
# 1    18A51A0402@apssdc.in
# 2    18A51A0403@apssdc.in
# 3    18A51A0404@apssdc.in
# 4    18A51A0405@apssdc.in
# Name: Email, dtype: object

# %% [markdown]
# ### Getting the row

# %%
rdata.iloc[50]
# Out:
# Roll Numbers              18A51A0451
# Email           18A51A0451@apssdc.in
# C                                  5
# Python                             4
# Pandas                            12
# Numpy                             51
# TotalMarks                        72
# Percentage                        18
# Status                          Fail
# Name: 50, dtype: object

# %%
rdata.iloc[10:20]
# Out:
#    Roll Numbers                 Email   C  Python  Pandas  Numpy  TotalMarks  \
# 10   18A51A0411  18A51A0411@apssdc.in  30      15      51     17         113
# 11   18A51A0412  18A51A0412@apssdc.in  50       6      63     36         155
# 12   18A51A0413  18A51A0413@apssdc.in  16      15      40     96         167
# 13   18A51A0414  18A51A0414@apssdc.in  80      50      31     68         229
# 14   18A51A0415  18A51A0415@apssdc.in  47      83      42      6         178
# 15   18A51A0416  18A51A0416@apssdc.in  70      64      35     75         244
# 16   18A51A0417  18A51A0417@apssdc.in  51      52      61      1         165
# 17   18A51A0418  18A51A0418@apssdc.in  81      55      59     72         267
# 18   18A51A0419  18A51A0419@apssdc.in  40      18      83      9         150
# 19   18A51A0420  18A51A0420@apssdc.in  20      20      25      1          66
#
#     Percentage Status
# 10       28.25   Fail
# 11       38.75   Fail
# 12       41.75   Pass
# 13       57.25   Pass
# ...

# %%
rdata.shape
# Out:
# (100, 9)

# %%
rdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 9 columns):
# Roll Numbers    100 non-null object
# Email           100 non-null object
# C               100 non-null int64
# Python          100 non-null int64
# Pandas          100 non-null int64
# Numpy           100 non-null int64
# TotalMarks      100 non-null int64
# Percentage      100 non-null float64
# Status          100 non-null object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 7.8+ KB

# %%
rdata.describe()
# Out:
#                C      Python      Pandas       Numpy  TotalMarks  Percentage
# count  100.00000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    44.93000   49.110000   49.130000   47.600000  190.770000   47.692500
# std     29.03055   27.621502   28.554628   32.127587   58.670085   14.667521
# min      1.00000    3.000000    0.000000    0.000000   61.000000   15.250000
# 25%     19.25000   26.000000   27.750000   15.000000  154.500000   38.625000
# 50%     45.00000   50.000000   51.500000   48.000000  192.500000   48.125000
# 75%     71.00000   73.000000   73.500000   75.250000  231.000000   57.750000
# max     99.00000   95.000000   99.000000   98.000000  327.000000   81.750000

# %%
rdata['Percentage'].plot(kind = 'hist')

# %% [markdown]
# # [Matplotlib](https://matplotlib.org)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Matplotlib Architecture
#
# 1. Scripting Layer (pyplot)
# 2. Artist Layer (Artist)
# 3. Backend Layer (FigureCanvas, Renderer, Event)
#
# ## Basic and Specialized Visualization Tools
# - Line Plots
# - Scatter Plots
# - Histograms
# - Bar Charts
# - Pie Charts
# - Box Plots

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line Plot

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.plot(x,y)
plt.title('Line Plot')
plt.xlabel('X_values')
plt.ylabel('Y_values')
plt.grid()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
import numpy as np
x = np.array([i for i in range(-5,5)])
y = x ** 2

plt.scatter(x,y,color = 'r')
plt.title('Scatter Plot')
plt.xlabel('X_values')
plt.ylabel('Y_values')
plt.grid()
plt.show()

# %% [markdown]
# ## Overlapping of two plots

# %%
import numpy as np
x = np.array([i for i in range(-5,5)])
y = x ** 2

plt.plot(x,y,'-.')
plt.scatter(x,y,color = 'r')
plt.title('Scatter Plot')
plt.xlabel('X_values')
plt.ylabel('Y_values')
plt.grid()
plt.show()

# %% [markdown]
# ## Box Plot

# %%
import pandas as pd
rdata = pd.read_csv('sdata.csv',index_col = 0)
x = rdata['Python']

plt.boxplot(x)
plt.show()

# %% [markdown]
# ## Histogram

# %%
x = rdata['Numpy']
plt.hist(x)
plt.grid()
plt.show()

# %% [markdown]
# ## Bar Graph

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
x = [1,2,3,4,5]
plt.pie(x,labels=x,radius=2)
plt.savefig('pie.png')

# %% [markdown]
# ## Sub Plots

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.figure(figsize=(5,5))
plt.subplot(2,2,1)
plt.pie(x,labels=x)

plt.subplot(2,2,2)
plt.plot(x,y)

plt.subplot(2,1,2)
plt.scatter(x,y)

plt.show()

# %%
# only canvas
plt.plot()
# Out:
# []

# %% [markdown]
# ## http://bit.ly/AITAM-Python-Adv-Feb-2020

# %% [markdown]
# ## http://bit.ly/APSSDC-Feedback

# %% [markdown]
# # www.awseducate.com
